# %% [markdown]
# ## 数据导入，观察，准备预处理

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"]
plt.rcParams["font.family"]="sans-serif"
plt.rcParams['axes.unicode_minus'] =False
import pandas as pd
from datetime import datetime

RAW_DATA = 'C:/Users/79918/Desktop/光伏数据.xlsx'

raw_data = pd.read_excel(r'C:/Users/79918/Desktop/光伏数据.xlsx')

print(raw_data.head())
# Out:
#    device_id  energy_consumption  calc_date  calc_time create_or_update_time
# 0        432                 0.0 2021-09-09         22     9/9/2021 23:59:00
# 1        455                 0.0 2021-09-09         22     9/9/2021 23:59:00
# 2        456                 0.0 2021-09-09         22     9/9/2021 23:59:00
# 3        457                 0.0 2021-09-09         22     9/9/2021 23:59:00
# 4        432                 0.0 2021-09-09         21     9/9/2021 22:59:00

# %%
raw_data['time'] = pd.to_datetime(raw_data["create_or_update_time"],format='%m/%d/%Y %H:%M:%S')
raw_data=raw_data.iloc[:,[0,1,5]]
raw_data
# Out:
#        device_id  energy_consumption                time
# 0            432                 0.0 2021-09-09 23:59:00
# 1            455                 0.0 2021-09-09 23:59:00
# 2            456                 0.0 2021-09-09 23:59:00
# 3            457                 0.0 2021-09-09 23:59:00
# 4            432                 0.0 2021-09-09 22:59:00
# ...          ...                 ...                 ...
# 12133        457                 0.0 2021-10-01 01:59:00
# 12134        432                 0.0 2021-10-01 00:59:00
# 12135        455                 0.0 2021-10-01 00:59:00
# 12136        456                 0.0 2021-10-01 00:59:00
# 12137        457                 0.0 2021-10-01 00:59:00
#
# [12138 rows x 3 columns]

# %%
raw_data['device_id'].unique()
# Out:
# array([432, 455, 456, 457, 449, 450, 454], dtype=int64)

# %%
raw_data_432=raw_data[raw_data["device_id"]==432].sort_values("time")
raw_data_455=raw_data[raw_data["device_id"]==455].sort_values("time")
raw_data_456=raw_data[raw_data["device_id"]==456].sort_values("time")
raw_data_457=raw_data[raw_data["device_id"]==457].sort_values("time")
raw_data_449=raw_data[raw_data["device_id"]==449].sort_values("time")
raw_data_450=raw_data[raw_data["device_id"]==450].sort_values("time")
raw_data_454=raw_data[raw_data["device_id"]==454].sort_values("time")
print(
raw_data_432.shape,
raw_data_455.shape,
raw_data_456.shape,
raw_data_457.shape,
raw_data_449.shape,
raw_data_450.shape,
raw_data_454.shape
)
# Out:
# (1704, 3) (2218, 3) (2218, 3) (2218, 3) (1170, 3) (1306, 3) (1304, 3)

# %%
plt.figure(figsize=(30,30))
plt.subplot(7, 1, 1)
plt.plot(raw_data_432["time"],raw_data_432["energy_consumption"])
plt.subplot(7, 1, 2)
plt.plot(raw_data_455["time"],raw_data_455["energy_consumption"])
plt.subplot(7, 1, 3)
plt.plot(raw_data_456["time"],raw_data_456["energy_consumption"])
plt.subplot(7, 1, 4)
plt.plot(raw_data_457["time"],raw_data_457["energy_consumption"])
plt.subplot(7, 1, 5)
plt.plot(raw_data_449["time"],raw_data_449["energy_consumption"])
plt.subplot(7, 1, 6)
plt.plot(raw_data_450["time"],raw_data_450["energy_consumption"])
plt.subplot(7, 1, 7)
plt.plot(raw_data_454["time"],raw_data_454["energy_consumption"])

# %% [markdown]
# ###### 后面3个还是不要了，中间一段都没有数据啊，保留432, 455, 456, 457，接下来分别对4个逆变器的数据进行清洗

# %%
#数据清洗，去除小于0和过大的异常值
raw_data_432=raw_data_432[raw_data_432["energy_consumption"]<=400.00]
raw_data_432=raw_data_432[raw_data_432["energy_consumption"]>=0]

raw_data_455=raw_data_455[raw_data_455["energy_consumption"]<=1000.00]
raw_data_455=raw_data_455[raw_data_455["energy_consumption"]>=0]

raw_data_456=raw_data_456[raw_data_456["energy_consumption"]<=1000.00]
raw_data_456=raw_data_456[raw_data_456["energy_consumption"]>=0]

raw_data_457=raw_data_457[raw_data_457["energy_consumption"]<=1000.00]
raw_data_457=raw_data_457[raw_data_457["energy_consumption"]>=0]

# %%
#看一下初步清洗的数据
plt.figure(figsize=(30,30))
plt.subplot(4, 1, 1)
plt.plot(raw_data_432["time"],raw_data_432["energy_consumption"])
plt.subplot(4, 1, 2)
plt.plot(raw_data_455["time"],raw_data_455["energy_consumption"])
plt.subplot(4, 1, 3)
plt.plot(raw_data_456["time"],raw_data_456["energy_consumption"])
plt.subplot(4, 1, 4)
plt.plot(raw_data_457["time"],raw_data_457["energy_consumption"])

# %%
#看一下清洗过后的数据集的shape
print(
raw_data_432.shape,
raw_data_455.shape,
raw_data_456.shape,
raw_data_457.shape
)
# Out:
# (1700, 3) (2208, 3) (2214, 3) (2206, 3)

# %%
raw_data_432=raw_data_432.iloc[:,[1]]
raw_data_455=raw_data_455.iloc[:,[1]]
raw_data_456=raw_data_456.iloc[:,[1]]
raw_data_457=raw_data_457.iloc[:,[1]]

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### 首先分别对4个逆变器的发电量试一下lstm

# %%
import math
import numpy 
import numpy as np
import pydot
import graphviz
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
  
# 创建数据集
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 加载数据
dataset = raw_data_432.values  
    
# 数据处理，归一化至0~1之间
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
    
# 划分训练集和测试集
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
# 创建测试集和训练集
look_back = 1
trainX, trainY = create_dataset(train, look_back)           #单步预测
testX, testY = create_dataset(test, look_back)
    
# 调整输入数据的格式
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))#（样本个数，1，输入的维度）
testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
    
######################################## 创建LSTM神经网络模型##############################################
model = Sequential()
model.add(LSTM(5, input_shape=(trainX.shape[1], trainX.shape[2])))#输入维度为1，时间窗的长度为1，隐含层神经元节点个数为120
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=5, batch_size=2, verbose=2)
    
# 预测
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
    
# 反归一化
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
    
# 计算得分
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
    
# 绘图
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot[1:])
plt.plot(testPredictPlot[1:])
plt.show()
# Out:
# Epoch 1/5
# 569/569 - 2s - loss: 0.0359
# Epoch 2/5
# 569/569 - 1s - loss: 0.0228
# Epoch 3/5
# 569/569 - 1s - loss: 0.0218
# Epoch 4/5
# 569/569 - 1s - loss: 0.0218
# Epoch 5/5
# 569/569 - 1s - loss: 0.0218
# Train Score: 11.25 RMSE
# Test Score: 11.79 RMSE

# %%
import math
import numpy as np
import pydot
import graphviz
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
  
# 创建数据集
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 加载数据
dataset = raw_data_455.values  
    
# 数据处理，归一化至0~1之间
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
    
# 划分训练集和测试集
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
# 创建测试集和训练集
look_back = 1
trainX, trainY = create_dataset(train, look_back)           #单步预测
testX, testY = create_dataset(test, look_back)
    
# 调整输入数据的格式
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))#（样本个数，1，输入的维度）
testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
    
######################################## 创建LSTM神经网络模型##############################################
model = Sequential()
model.add(LSTM(2, input_shape=(trainX.shape[1], trainX.shape[2])))#输入维度为1，时间窗的长度为1，隐含层神经元节点个数为120
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=5, batch_size=2, verbose=2)
    
# 预测
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
    
# 反归一化
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
    
# 计算得分
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
    
# 绘图
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot[1:])
plt.plot(testPredictPlot[1:])
plt.show()
# Out:
# Epoch 1/5
# 739/739 - 3s - loss: 0.0346
# Epoch 2/5
# 739/739 - 1s - loss: 0.0176
# Epoch 3/5
# 739/739 - 1s - loss: 0.0159
# Epoch 4/5
# 739/739 - 1s - loss: 0.0158
# Epoch 5/5
# 739/739 - 1s - loss: 0.0157
# Train Score: 11.87 RMSE
# Test Score: 8.54 RMSE

# %%
import math
import numpy as np
import pydot
import graphviz
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
  
# 创建数据集
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 加载数据
dataset = raw_data_456.values  
    
# 数据处理，归一化至0~1之间
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
    
# 划分训练集和测试集
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
# 创建测试集和训练集
look_back = 1
trainX, trainY = create_dataset(train, look_back)           #单步预测
testX, testY = create_dataset(test, look_back)
    
# 调整输入数据的格式
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))#（样本个数，1，输入的维度）
testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
    
######################################## 创建LSTM神经网络模型##############################################
model = Sequential()
model.add(LSTM(2, input_shape=(trainX.shape[1], trainX.shape[2])))#输入维度为1，时间窗的长度为1，隐含层神经元节点个数为120
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=5, batch_size=2, verbose=2)
    
# 预测
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
    
# 反归一化
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
    
# 计算得分
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
    
# 绘图
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot[1:])
plt.plot(testPredictPlot[1:])
plt.show()
# Out:
# Epoch 1/5
# 741/741 - 3s - loss: 0.0372
# Epoch 2/5
# 741/741 - 1s - loss: 0.0188
# Epoch 3/5
# 741/741 - 1s - loss: 0.0156
# Epoch 4/5
# 741/741 - 1s - loss: 0.0155
# Epoch 5/5
# 741/741 - 1s - loss: 0.0154
# Train Score: 11.57 RMSE
# Test Score: 9.35 RMSE

# %%
import math
import numpy as np
import pydot
import graphviz
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
  
# 创建数据集
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 加载数据
dataset = raw_data_457.values  
    
# 数据处理，归一化至0~1之间
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
    
# 划分训练集和测试集
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
# 创建测试集和训练集
look_back = 1
trainX, trainY = create_dataset(train, look_back)           #单步预测
testX, testY = create_dataset(test, look_back)
    
# 调整输入数据的格式
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))#（样本个数，1，输入的维度）
testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
    
######################################## 创建LSTM神经网络模型##############################################
model = Sequential()
model.add(LSTM(5, input_shape=(trainX.shape[1], trainX.shape[2])))#输入维度为1，时间窗的长度为1，隐含层神经元节点个数为120
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=5, batch_size=3, verbose=2)
    
# 预测
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
    
# 反归一化
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
    
# 计算得分
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
    
# 绘图
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot[1:])
plt.plot(testPredictPlot[1:])
plt.show()
# Out:
# Epoch 1/5
# 492/492 - 2s - loss: 0.0618
# Epoch 2/5
# 492/492 - 1s - loss: 0.0280
# Epoch 3/5
# 492/492 - 1s - loss: 0.0193
# Epoch 4/5
# 492/492 - 1s - loss: 0.0187
# Epoch 5/5
# 492/492 - 1s - loss: 0.0185
# Train Score: 15.36 RMSE
# Test Score: 11.75 RMSE

# %% [markdown]
# **结论：4个逆变器分开的结果都还可以，RMSE在7-10左右**

# %% [markdown]
# ### 现在试一下4个逆变器合起来

# %%
from pycaret.regression import *

# %%
raw_data=raw_data[raw_data["device_id"].isin([432,455,456,457])]#只选出4个逆变器的数据
raw_data=raw_data[raw_data["energy_consumption"]<=800.00]#洗数据
raw_data=raw_data[raw_data["energy_consumption"]>=0]#洗数据
raw=raw_data.groupby(['time']).sum().reset_index()#汇总
raw=raw[raw["device_id"]==1800]#保留4个逆变器都记录到的观测
raw
# Out:
#                     time  device_id  energy_consumption
# 1    2021-07-27 11:59:00       1800               110.3
# 4    2021-07-27 14:59:00       1800               178.5
# 5    2021-07-27 15:59:00       1800               131.4
# 6    2021-07-27 16:59:00       1800               146.9
# 7    2021-07-27 17:59:00       1800                26.2
# ...                  ...        ...                 ...
# 2212 2021-10-27 19:59:00       1800                 0.0
# 2213 2021-10-27 20:59:00       1800                 0.0
# 2214 2021-10-27 21:59:00       1800                 0.0
# 2215 2021-10-27 22:59:00       1800                 0.0
# 2219 2021-10-28 02:00:00       1800                 0.0
#
# [1683 rows x 3 columns]

# %%
plt.figure(figsize=(30,8))
plt.plot(raw["energy_consumption"])

# %%
raw=raw.iloc[:,[0,2]]
raw['TIME_HOUR'] = raw['time'].dt.hour
raw['TIME_MONTH'] = raw['time'].dt.month
raw=raw.iloc[:,[1,2,3]]
raw
# Out:
#       energy_consumption  TIME_HOUR  TIME_MONTH
# 1                  110.3         11           7
# 4                  178.5         14           7
# 5                  131.4         15           7
# 6                  146.9         16           7
# 7                   26.2         17           7
# ...                  ...        ...         ...
# 2212                 0.0         19          10
# 2213                 0.0         20          10
# 2214                 0.0         21          10
# 2215                 0.0         22          10
# 2219                 0.0          2          10
#
# [1683 rows x 3 columns]

# %% [markdown]
# #### 先试一下pycaret

# %%
dataset = raw.values  
train_size = int(len(dataset) * 0.67)

# %%
data_train = raw_data.iloc[:train_size,:].reset_index(drop=True)
data_unseen = raw_data.iloc[train_size:,:]

# %%
reg_test = setup(data = raw, target = 'energy_consumption', session_id=123)
# Out:
# <style  type="text/css" >
# #T_52c7313a_b189_11ec_8bec_44af286ea5d7row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_52c7313a_b189_11ec_8bec_44af286ea5d7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row1_col1" class="data row1 col1" >energy_consumption</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row2_col1" class="data row2 col1" >(1683, 3)</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row4_col1" class="data row4 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row5_col1" class="data row5 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row9_col1" class="data row9 col1" >(1178, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row10_col1" class="data row10 col1" >(505, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52c7313a_b189_11ec_8bec_44af286ea5d7level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_52c7313a_b189_11ec_8bec_44af286ea5d7row1

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_62c071ba_b189_11ec_b9ab_44af286ea5d7 th {
#           text-align: left;
#     }#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col5,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row12_col0,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row12_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row12_col2,#T_62c071 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col2,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col3,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col4,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col1,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col6,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row0_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row1_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row2_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row3_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row4_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row5_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row6_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row7_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row8_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row9_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row10_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row11_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row12_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row13_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7row15_col7,#T_62c071ba_b189_11ec_b9ab_44af286ea5d7
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=123)

# %%
import math
import time
import numpy 
import numpy as np
import pydot
import graphviz
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from numpy import concatenate  # 数组拼接

from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
  
# 创建数据集
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 加载数据
dataset = raw.iloc[:,[0]].values  
    
# 数据处理，归一化至0~1之间
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
    
# 划分训练集和测试集
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
# 创建测试集和训练集
look_back = 1
trainX, trainY = create_dataset(train, look_back)           #单步预测
testX, testY = create_dataset(test, look_back)
    
# 调整输入数据的格式
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))#（样本个数，1，输入的维度）
testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
    
######################################## 创建LSTM神经网络模型##############################################
start = time.perf_counter()

model = Sequential()
model.add(LSTM(4, input_shape=(trainX.shape[1], trainX.shape[2])))#输入维度为1，时间窗的长度为1，隐含层神经元节点个数为120
model.add(Dense(20))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=5, batch_size=2, verbose=2)
    
# 预测
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# 反归一化
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

end = time.perf_counter()
print("time consuming : %.2fs"%(end - start))

# 计算得分
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
    
# 绘图
plt.figure(figsize=(30,8))

trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.plot(scaler.inverse_transform(dataset)[:])
plt.plot(trainPredictPlot[1:])
plt.plot(testPredictPlot[1:])
plt.show()
# Out:
# Epoch 1/5
# 563/563 - 2s - loss: 0.0320
# Epoch 2/5
# 563/563 - 1s - loss: 0.0169
# Epoch 3/5
# 563/563 - 1s - loss: 0.0170
# Epoch 4/5
# 563/563 - 1s - loss: 0.0168
# Epoch 5/5
# 563/563 - 1s - loss: 0.0168
# time consuming : 6.33s
# Train Score: 31.03 RMSE
# Test Score: 28.10 RMSE

# %%
plt.figure(figsize=(30,8))

plt.plot(scaler.inverse_transform(dataset)[1500:])
plt.plot(trainPredictPlot[1501:])
plt.plot(testPredictPlot[1501:])
plt.show()

# %% [markdown]
# ## 设计指标评价预测效果

# %% [markdown]
# ### **指标1定义：bias<?占总体的比例**

# %%
bias=abs(testY[0][:len(testPredict)-1]-testPredict[1:,0])/(testY[0][:len(testPredict)-1]+0.0000000000000000000000000000000000001)
i=np.linspace(0,1,51)
bias_i=[]
for p in i:
    bias_i.append(((np.sum(bias<=p))/len(bias)))
    print("About %.3f points under %.2f bias"%(((np.sum(bias<=p))/len(bias)),p))
plt.plot(i,bias_i)
plt.title('# under bias threshold')
plt.xlabel('threshold')
plt.ylabel('T')
# Out:
# About 0.485 points under 0.00 bias
# About 0.564 points under 0.02 bias
# About 0.635 points under 0.04 bias
# About 0.687 points under 0.06 bias
# About 0.741 points under 0.08 bias
# About 0.792 points under 0.10 bias
# About 0.817 points under 0.12 bias
# About 0.852 points under 0.14 bias
# About 0.875 points under 0.16 bias
# About 0.893 points under 0.18 bias
# About 0.897 points under 0.20 bias
# About 0.902 points under 0.22 bias
# About 0.908 points under 0.24 bias
# About 0.911 points under 0.26 bias
# About 0.913 points under 0.28 bias
# About 0.917 points under 0.30 bias
# About 0.919 points under 0.32 bias
# About 0.920 points under 0.34 bias
# About 0.922 points under 0.36 bias
# About 0.926 points under 0.38 bias
# About 0.929 points under 0.40 bias
# About 0.931 points under 0.42 bias
# About 0.933 points under 0.44 bias
# About 0.940 points under 0.46 bias
# About 0.944 points under 0.48 bias
# About 0.948 points under 0.50 bias
# About 0.948 points under 0.52 bias
# About 0.953 points under 0.54 bias
# About 0.953 points under 0.56 bias
# About 0.953 points under 0.58 bias
# About 0.957 points under 0.60 bias
# About 0.957 points under 0.62 bias
# About 0.960 points under 0.64 bias
# About 0.962 points under 0.66 bias
# About 0.962 points under 0.68 bias
# About 0.962 points under 0.70 bias
# About 0.964 points under 0.72 bias
# About 0.966 points under 0.74 bias
# About 0.966 points under 0.76 bias
# About 0.966 points under 0.78 bias
# About 0.967 points under 0.80 bias
# About 0.967 points under 0.82 bias
# About 0.967 points under 0.84 bias
# About 0.967 points under 0.86 bias
# About 0.969 points under 0.88 bias
# About 0.969 points under 0.90 bias
# About 0.969 points under 0.92 bias
# About 0.969 points under 0.94 bias
# About 0.969 points under 0.96 bias
# About 0.969 points under 0.98 bias
# About 0.969 points under 1.00 bias
# Text(0, 0.5, 'T')

# %% [markdown]
# **可以发现：80%的输出结果与实际值的误差在10%以内**

# %% [markdown]
# ### **指标2定义：RMSE均方根误差**

# %% [markdown]
# ![RMSE](./0.jpg)

# %%
a=np.min(testPredict[:,0])
b=np.min(trainPredict[:,0])
testPredict[:,0][testPredict[:,0]<=a] = 0
trainPredict[:,0][trainPredict[:,0]<=b] = 0

trainRMSE = math.sqrt(mean_squared_error(trainY[0][:len(trainPredict)-1], trainPredict[1:,0]))
print('Train Score: %.2f RMSE' % (trainRMSE))
testRMSE = math.sqrt(mean_squared_error(testY[0][:len(testPredict)-1], testPredict[1:,0]))
print('Test Score: %.2f RMSE' % (testRMSE))
# Out:
# Train Score: 35.85 RMSE
# Test Score: 32.25 RMSE
